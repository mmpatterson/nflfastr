# %%
import pandas as pd
import requests
import os
os.environ['NO_PROXY'] = '127.0.0.1'

# %%
master_df = pd.DataFrame()
for year in range(2019, 2021, 1):
    year_df = pd.read_csv(f'https://github.com/nflverse/nflfastR-data/blob/master/data/play_by_play_{year}.csv.gz?raw=true', compression = 'gzip')
    master_df = master_df.append(year_df)

# %%
master_df.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 1       36  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 2       51  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 3       79  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 4      100  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     0
# 1     1     ATL         away     MIN  ...             0                     0
# 2     1     ATL         away     MIN  ...             0                     0
# 3     1     ATL         away     MIN  ...             0                     0
# 4     1     ATL         away     MIN  ...             0                     0
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0       NaN       NaN                NaN                  NaN          NaN
# 1 -0.000000       NaN                NaN                  NaN          NaN
# 2 -1.658763       NaN                NaN                  NaN          NaN
# 3 -0.538914       NaN                NaN                  NaN          NaN
# 4  0.142138       NaN                NaN                  NaN          NaN
#
#    xyac_fd     xpass    pass_oe
# 0      NaN       NaN        NaN
# 1      NaN       NaN        NaN
# 2      NaN  0.486799  51.320082
# 3      NaN  0.639994 -63.999379
# 4      NaN  0.933516   6.648362
#
# [5 rows x 370 columns]

# %%
master_df.query("game_id == '2019_01_ATL_MIN'").sort_values('play_id')
# Out:
#      play_id          game_id  old_game_id home_team away_team season_type  \
# 0          1  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 1         36  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 2         51  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 3         79  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 4        100  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 5        121  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 6        148  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 7        185  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 8        214  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 9        239  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 10       255  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 11       277  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 12       298  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 13       319  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 14       342  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 15       368  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 16       392  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 17       413  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 18       472  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 19       494  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 20       510  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 21       525  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 22       546  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 23       570  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 24       593  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 25       615  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 26       639  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 27       663  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 28       689  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 29       713  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# ..       ...              ...          ...       ...       ...         ...
# 141     3387  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 142     3404  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 143     3427  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 144     3448  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 145     3469  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 146     3490  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 147     3513  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 148     3555  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 149     3578  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 150     3602  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 151     3626  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 152     3650  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 153     3672  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 154     3705  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 155     3727  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 156     3751  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 157     3781  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 158     3805  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 159     3822  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 160     3841  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 161     3858  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 162     3882  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 163     3906  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 164     3923  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 165     3958  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 166     3983  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 167     3997  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 168     4032  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 169     4053  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
# 170     4074  2019_01_ATL_MIN   2019090804       MIN       ATL         REG
#
#      week posteam posteam_type defteam  ... out_of_bounds  \
# 0       1     NaN          NaN     NaN  ...             0
# 1       1     ATL         away     MIN  ...             0
# 2       1     ATL         away     MIN  ...             0
# 3       1     ATL         away     MIN  ...             0
# 4       1     ATL         away     MIN  ...             0
# 5       1     ATL         away     MIN  ...             0
# 6       1     MIN         home     ATL  ...             1
# 7       1     MIN         home     ATL  ...             1
# 8       1     MIN         home     ATL  ...             0
# 9       1     MIN         home     ATL  ...             0
# 10      1     ATL         away     MIN  ...             0
# 11      1     ATL         away     MIN  ...             0
# 12      1     ATL         away     MIN  ...             0
# 13      1     ATL         away     MIN  ...             0
# 14      1     ATL         away     MIN  ...             0
# 15      1     MIN         home     ATL  ...             0
# 16      1     MIN         home     ATL  ...             0
# 17      1     MIN         home     ATL  ...             0
# 18      1     MIN         home     ATL  ...             0
# 19      1     MIN         home     ATL  ...             0
# 20      1     ATL         away     MIN  ...             0
# 21      1     ATL         away     MIN  ...             0
# 22      1     ATL         away     MIN  ...             0
# 23      1     ATL         away     MIN  ...             0
# 24      1     ATL         away     MIN  ...             0
# 25      1     ATL         away     MIN  ...             0
# 26      1     ATL         away     MIN  ...             0
# 27      1     ATL         away     MIN  ...             1
# 28      1     ATL         away     MIN  ...             0
# 29      1     ATL         away     MIN  ...             0
# ..    ...     ...          ...     ...  ...           ...
# 141     1     NaN          NaN     NaN  ...             0
# 142     1     MIN         home     ATL  ...             0
# 143     1     MIN         home     ATL  ...             0
# 144     1     MIN         home     ATL  ...             0
# 145     1     MIN         home     ATL  ...             0
# 146     1     MIN         home     ATL  ...             0
# 147     1     MIN         home     ATL  ...             0
# 148     1     ATL         away     MIN  ...             0
# 149     1     ATL         away     MIN  ...             0
# 150     1     ATL         away     MIN  ...             0
# 151     1     ATL         away     MIN  ...             0
# 152     1     ATL         away     MIN  ...             0
# 153     1     ATL         away     MIN  ...             0
# 154     1     ATL         away     MIN  ...             0
# 155     1     ATL         away     MIN  ...             0
# 156     1     ATL         away     MIN  ...             0
# 157     1     ATL         away     MIN  ...             0
# 158     1     NaN          NaN     NaN  ...             0
# 159     1     ATL         away     MIN  ...             0
# 160     1     NaN          NaN     NaN  ...             0
# 161     1     ATL         away     MIN  ...             0
# 162     1     ATL         away     MIN  ...             0
# 163     1     NaN          NaN     NaN  ...             0
# 164     1     ATL         away     MIN  ...             0
# 165     1     ATL         away     MIN  ...             0
# 166     1     ATL         away     MIN  ...             0
# 167     1     MIN         home     ATL  ...             0
# 168     1     MIN         home     ATL  ...             0
# 169     1     MIN         home     ATL  ...             0
# 170     1     NaN          NaN     NaN  ...             0
#
#      home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 0                       0       NaN       NaN                NaN
# 1                       0 -0.000000       NaN                NaN
# 2                       0 -1.658763       NaN                NaN
# 3                       0 -0.538914       NaN                NaN
# 4                       0  0.142138       NaN                NaN
# 5                       0 -4.034299       NaN                NaN
# 6                       0 -1.125093       NaN                NaN
# 7                       0  0.258130  0.747668           6.732305
# 8                       0  2.785377  0.304460           2.208216
# 9                       0  0.051172       NaN                NaN
# 10                      0 -0.612925       NaN                NaN
# 11                      0 -0.199326       NaN                NaN
# 12                      0 -0.474208       NaN                NaN
# 13                      0  1.343514       NaN                NaN
# 14                      0 -4.834618  0.326493           4.293836
# 15                      0 -0.544799  0.732483           6.289610
# 16                      0  1.913411       NaN                NaN
# 17                      0 -0.486268       NaN                NaN
# 18                      0  2.439273       NaN                NaN
# 19                      0  0.051172       NaN                NaN
# 20                      0 -0.000000       NaN                NaN
# 21                      0 -0.593575       NaN                NaN
# 22                      0 -0.297915  1.224435           7.306100
# 23                      0  1.358697       NaN                NaN
# 24                      0 -0.563496       NaN                NaN
# 25                      0 -0.252092  0.768247           3.996794
# 26                      0  1.667733  0.275905           4.289433
# 27                      0 -0.875386       NaN                NaN
# 28                      0  2.358596  0.686943           3.495630
# 29                      0 -0.850296       NaN                NaN
# ..                    ...       ...       ...                ...
# 141                     0  0.000000       NaN                NaN
# 142                     0  0.370648       NaN                NaN
# 143                     0 -0.575172       NaN                NaN
# 144                     0 -0.789851       NaN                NaN
# 145                     0 -0.630553       NaN                NaN
# 146                     0 -0.637766       NaN                NaN
# 147                     0 -1.133432       NaN                NaN
# 148                     0 -0.705883       NaN                NaN
# 149                     0  0.169873  0.840398           7.489084
# 150                     0  0.881645  0.204278           2.998203
# 151                     0  0.379763  0.665882           4.822583
# 152                     0 -0.655769  0.504721           6.102499
# 153                     0  1.311119       NaN                NaN
# 154                     0 -0.614799  0.510098           4.972590
# 155                     0  0.221636  0.712743           4.624906
# 156                     0  1.042828       NaN                NaN
# 157                     0  0.354519  0.784407           6.146922
# 158                     0 -0.000000       NaN                NaN
# 159                     0 -1.445922       NaN                NaN
# 160                     0 -0.000000       NaN                NaN
# 161                     0  0.312172  0.882216           5.587594
# 162                     0  1.921903  0.250982           3.400966
# 163                     0 -0.000000       NaN                NaN
# 164                     0  1.434441  0.513294           3.824982
# 165                     0  0.994815       NaN                NaN
# 166                     0 -0.947000       NaN                NaN
# 167                     0  1.258065       NaN                NaN
# 168                     0 -0.379948       NaN                NaN
# 169                     0 -1.557220       NaN                NaN
# 170                     0       NaN       NaN                NaN
#
#      xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 0                    NaN          NaN       NaN       NaN        NaN
# 1                    NaN          NaN       NaN       NaN        NaN
# 2                    NaN          NaN       NaN  0.486799  51.320082
# 3                    NaN          NaN       NaN  0.639994 -63.999379
# 4                    NaN          NaN       NaN  0.933516   6.648362
# 5                    NaN          NaN       NaN       NaN        NaN
# 6                    NaN          NaN       NaN  0.408242 -40.824211
# 7                    6.0     0.505931  0.053389  0.705088  29.491204
# 8                    0.0     0.999368  0.484263  0.803992  19.600838
# 9                    NaN          NaN       NaN       NaN        NaN
# 10                   NaN          NaN       NaN       NaN        NaN
# 11                   NaN          NaN       NaN  0.440971 -44.097072
# 12                   NaN          NaN       NaN  0.588535 -58.853549
# 13                   NaN          NaN       NaN  0.918794        NaN
# 14                   2.0     1.000000  0.998632  0.476091  52.390891
# 15                   5.0     0.536914  0.250869  0.478856  52.114406
# 16                   NaN          NaN       NaN  0.727231 -72.723097
# 17                   NaN          NaN       NaN  0.433803  56.619674
# 18                   NaN          NaN       NaN  0.588482 -58.848172
# 19                   NaN          NaN       NaN       NaN        NaN
# 20                   NaN          NaN       NaN       NaN        NaN
# 21                   NaN          NaN       NaN  0.476110 -47.610962
# 22                   6.0     0.629646  0.351390  0.669014  33.098555
# 23                   NaN          NaN       NaN  0.969930        NaN
# 24                   NaN          NaN       NaN  0.492886  50.711447
# 25                   2.0     0.587632  0.262166  0.537916  46.208358
# 26                   2.0     0.974920  0.974920  0.967478   3.252190
# 27                   NaN          NaN       NaN  0.499038 -49.903828
# 28                   2.0     0.979162  0.305905  0.803561  19.643861
# 29                   NaN          NaN       NaN  0.472046 -47.204649
# ..                   ...          ...       ...       ...        ...
# 141                  NaN          NaN       NaN       NaN        NaN
# 142                  NaN          NaN       NaN  0.211786 -21.178621
# 143                  NaN          NaN       NaN  0.197515 -19.751486
# 144                  NaN          NaN       NaN  0.321041 -32.104087
# 145                  NaN          NaN       NaN  0.715976 -71.597636
# 146                  NaN          NaN       NaN  0.494476        NaN
# 147                  NaN          NaN       NaN       NaN        NaN
# 148                  NaN          NaN       NaN  0.797727        NaN
# 149                  6.0     0.645640  0.097486  0.784606  21.539408
# 150                  1.0     1.000000  0.998869  0.794733  20.526719
# 151                  3.0     0.828753  0.287835  0.835220  16.478044
# 152                  4.0     1.000000  1.000000  0.813909  18.609142
# 153                  NaN          NaN       NaN  0.922577   7.742327
# 154                  3.0     1.000000  1.000000  0.848599  15.140074
# 155                  3.0     0.557218  0.233714  0.846049  15.395123
# 156                  NaN          NaN       NaN  0.899373  10.062736
# 157                  5.0     0.610359  0.240488  0.850930  14.906961
# 158                  NaN          NaN       NaN       NaN        NaN
# 159                  NaN          NaN       NaN  0.843290  15.671027
# 160                  NaN          NaN       NaN       NaN        NaN
# 161                  4.0     0.303507  0.193216  0.941505   5.849469
# 162                  2.0     0.999106  0.999106  0.885031  11.496854
# 163                  NaN          NaN       NaN       NaN        NaN
# 164                  3.0     0.994909  0.410591  0.906277   9.372258
# 165                  NaN          NaN       NaN  0.761919  23.808134
# 166                  NaN          NaN       NaN       NaN        NaN
# 167                  NaN          NaN       NaN       NaN        NaN
# 168                  NaN          NaN       NaN       NaN        NaN
# 169                  NaN          NaN       NaN       NaN        NaN
# 170                  NaN          NaN       NaN       NaN        NaN
#
# [171 rows x 370 columns]

# %%
columns = ['play_id', 'game_id', 'home_team', 'away_team', 'qb_epa']

NO_PROXY = {
    'no': 'pass',
}

# %%
json = {'columns': columns, }

# %%
pd.DataFrame(requests.post('https://nflfastr.herokuapp.com/api/v1.0/play-by-play/2018', json = json).json()).reset_index(drop = True).sort_values('game_id')
# Out:
#        play_id          game_id home_team away_team    qb_epa
# 0            1  2018_01_ATL_PHI       PHI       ATL       NaN
# 5780      3700  2018_01_ATL_PHI       PHI       ATL -0.002048
# 5891      3736  2018_01_ATL_PHI       PHI       ATL  0.038494
# 45986     2032  2018_01_ATL_PHI       PHI       ATL  0.030620
# 6002      3758  2018_01_ATL_PHI       PHI       ATL -1.025247
# 6113      3791  2018_01_ATL_PHI       PHI       ATL -1.038892
# 6224      3815  2018_01_ATL_PHI       PHI       ATL -0.925102
# 5669      3678  2018_01_ATL_PHI       PHI       ATL -0.964164
# 6335      3844  2018_01_ATL_PHI       PHI       ATL  0.241937
# 2780      3066  2018_01_ATL_PHI       PHI       ATL -0.783892
# 6557      3904  2018_01_ATL_PHI       PHI       ATL -0.453192
# 6668       366  2018_01_ATL_PHI       PHI       ATL -0.758654
# 6669      3928  2018_01_ATL_PHI       PHI       ATL -0.712498
# 46097     2055  2018_01_ATL_PHI       PHI       ATL -0.050756
# 6780      3950  2018_01_ATL_PHI       PHI       ATL  1.874323
# 6446      3868  2018_01_ATL_PHI       PHI       ATL -1.107279
# 6891      3979  2018_01_ATL_PHI       PHI       ATL  0.301497
# 5558      3661  2018_01_ATL_PHI       PHI       ATL  0.000000
# 2891      3095  2018_01_ATL_PHI       PHI       ATL -1.410882
# 4447      3439  2018_01_ATL_PHI       PHI       ATL  0.215001
# 3002      3124  2018_01_ATL_PHI       PHI       ATL  0.731463
# 4558      3460  2018_01_ATL_PHI       PHI       ATL  1.598228
# 4669      3481  2018_01_ATL_PHI       PHI       ATL -5.592424
# 4780      3507  2018_01_ATL_PHI       PHI       ATL  0.948535
# 23335      776  2018_01_ATL_PHI       PHI       ATL -1.293429
# 5557       344  2018_01_ATL_PHI       PHI       ATL -1.345258
# 4891      3531  2018_01_ATL_PHI       PHI       ATL  1.958251
# 225       2474  2018_01_ATL_PHI       PHI       ATL -0.555909
# 5113      3569  2018_01_ATL_PHI       PHI       ATL  0.000000
# 45875     1989  2018_01_ATL_PHI       PHI       ATL  0.345006
# ...        ...              ...       ...       ...       ...
# 41977     2055    2018_21_NE_LA        LA        NE  0.000000
# 41978     2077    2018_21_NE_LA        LA        NE       NaN
# 41980     2094    2018_21_NE_LA        LA        NE  0.000000
# 41981     2109    2018_21_NE_LA        LA        NE -0.686916
# 41982     2131    2018_21_NE_LA        LA        NE  1.632558
# 41961     1701    2018_21_NE_LA        LA        NE  0.549355
# 41984     2178    2018_21_NE_LA        LA        NE -0.900252
# 41960     1681    2018_21_NE_LA        LA        NE -0.534453
# 41958     1639    2018_21_NE_LA        LA        NE -0.231546
# 41937     1142    2018_21_NE_LA        LA        NE  0.186157
# 41938     1173    2018_21_NE_LA        LA        NE -0.042521
# 41939     1198    2018_21_NE_LA        LA        NE  2.084646
# 41940     1229    2018_21_NE_LA        LA        NE -0.399492
# 41941     1251    2018_21_NE_LA        LA        NE -0.567367
# 41942     1273    2018_21_NE_LA        LA        NE -0.763197
# 41943     1298    2018_21_NE_LA        LA        NE  0.740413
# 41944     1317    2018_21_NE_LA        LA        NE  0.060748
# 41945     1340    2018_21_NE_LA        LA        NE -0.057505
# 41947     1362    2018_21_NE_LA        LA        NE  1.266555
# 41948     1403    2018_21_NE_LA        LA        NE -0.240760
# 41949     1428    2018_21_NE_LA        LA        NE -0.976199
# 41950     1450    2018_21_NE_LA        LA        NE -1.609392
# 41951     1472    2018_21_NE_LA        LA        NE -0.733008
# 41952     1505    2018_21_NE_LA        LA        NE -0.151929
# 41953     1527    2018_21_NE_LA        LA        NE -0.688170
# 41954     1549    2018_21_NE_LA        LA        NE -0.710672
# 41955     1574    2018_21_NE_LA        LA        NE -1.565961
# 41956     1617    2018_21_NE_LA        LA        NE -0.009208
# 41959     1661    2018_21_NE_LA        LA        NE -2.984808
# 42083     4306    2018_21_NE_LA        LA        NE       NaN
#
# [47874 rows x 5 columns]

# %%
columns = ['first_name', 'last_name', 'position', 'team']
json = {'columns':columns}

# %%
requests.get('https://nflfastr.herokuapp.com/api/v1.0/roster/2020').json()
# Out:
# [{'birth_date': '1996-03-28',
#   'college': 'Michigan',
#   'depth_chart_position': 'C',
#   'espn_id': 3115972.0,
#   'fantasy_data_id': 19898.0,
#   'first_name': 'Mason',
#   'full_name': 'Mason Cole',
#   'gsis_id': '00-0034785',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3115972.png',
#   'height': '6-5',
#   'high_school': 'East Lake (FL)',
#   'jersey_number': 52.0,
#   'last_name': 'Cole',
#   'pff_id': 45547.0,
#   'position': 'C',
#   'rotowire_id': 12795.0,
#   'season': 2020,
#   'sleeper_id': 5062,
#   'sportradar_id': '53d25371-e3ce-4030-8d0a-82def5cdc600',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 292.0,
#   'yahoo_id': 31067.0,
#   'years_exp': nan},
#  {'birth_date': '1996-02-08',
#   'college': 'Georgia',
#   'depth_chart_position': 'C',
#   'espn_id': 3128707.0,
#   'fantasy_data_id': 20763.0,
#   'first_name': 'Lamont',
#   'full_name': 'Lamont Gaillard',
#   'gsis_id': '00-0035536',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3128707.png',
#   'height': '6-3',
#   'high_school': 'Pine Forest (NC)',
#   'jersey_number': 53.0,
#   'last_name': 'Gaillard',
#   'pff_id': 46618.0,
#   'position': 'C',
#   'rotowire_id': 13678.0,
#   'season': 2020,
#   'sleeper_id': 6058,
#   'sportradar_id': '0c8b0581-9ed2-488b-bcaa-ef783261dfd1',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 305.0,
#   'yahoo_id': 32011.0,
#   'years_exp': nan},
#  {'birth_date': '1998-01-18',
#   'college': 'Washington',
#   'depth_chart_position': 'NB',
#   'espn_id': 4038999.0,
#   'fantasy_data_id': 20888.0,
#   'first_name': 'Byron',
#   'full_name': 'Byron Murphy',
#   'gsis_id': '00-0035236',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4038999.png',
#   'height': '5-11',
#   'high_school': 'Saguaro (AZ)',
#   'jersey_number': 33.0,
#   'last_name': 'Murphy',
#   'pff_id': 44027.0,
#   'position': 'CB',
#   'rotowire_id': 13560.0,
#   'season': 2020,
#   'sleeper_id': 5864,
#   'sportradar_id': 'c025b513-9431-4097-bc25-9777bf08f846',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 190.0,
#   'yahoo_id': 31865.0,
#   'years_exp': nan},
#  {'birth_date': '1989-06-06',
#   'college': 'Nebraska',
#   'depth_chart_position': nan,
#   'espn_id': 13975.0,
#   'fantasy_data_id': 13135.0,
#   'first_name': 'Prince',
#   'full_name': 'Prince Amukamara',
#   'gsis_id': '00-0027957',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/13975.png',
#   'height': '6-0',
#   'high_school': 'Apollo (AZ)',
#   'jersey_number': 20.0,
#   'last_name': 'Amukamara',
#   'pff_id': 6171.0,
#   'position': 'CB',
#   'rotowire_id': 7509.0,
#   'season': 2020,
#   'sleeper_id': 908,
#   'sportradar_id': 'f1879cfa-4c07-4140-9da0-c7ebe9af2dfd',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 204.0,
#   'yahoo_id': 24806.0,
#   'years_exp': nan},
#  {'birth_date': '1995-07-16',
#   'college': 'Arizona',
#   'depth_chart_position': nan,
#   'espn_id': 3821572.0,
#   'fantasy_data_id': 22171.0,
#   'first_name': 'Jace',
#   'full_name': 'Jace Whittaker',
#   'gsis_id': '00-0036043',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3821572.png',
#   'height': '5-11',
#   'high_school': 'Oceanside (CA)',
#   'jersey_number': 39.0,
#   'last_name': 'Whittaker',
#   'pff_id': 50465.0,
#   'position': 'CB',
#   'rotowire_id': 14793.0,
#   'season': 2020,
#   'sleeper_id': 7169,
#   'sportradar_id': '528bf5c9-1d23-40c3-adda-df21f8f0e2ab',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 185.0,
#   'yahoo_id': 33089.0,
#   'years_exp': nan},
#  {'birth_date': '1994-03-22',
#   'college': 'Oklahoma State',
#   'depth_chart_position': 'LCB',
#   'espn_id': 2977742.0,
#   'fantasy_data_id': 18293.0,
#   'first_name': 'Kevin',
#   'full_name': 'Kevin Peterson',
#   'gsis_id': '00-0032848',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2977742.png',
#   'height': '5-11',
#   'high_school': 'Wagoner (OK)',
#   'jersey_number': 27.0,
#   'last_name': 'Peterson',
#   'pff_id': 11302.0,
#   'position': 'CB',
#   'rotowire_id': 11101.0,
#   'season': 2020,
#   'sleeper_id': 3527,
#   'sportradar_id': '30e539c3-74dd-4a9a-9ebb-4bdd0f0d39f8',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 185.0,
#   'yahoo_id': 29924.0,
#   'years_exp': nan},
#  {'birth_date': '1984-04-16',
#   'college': 'South Carolina',
#   'depth_chart_position': 'RCB',
#   'espn_id': 9610.0,
#   'fantasy_data_id': 4490.0,
#   'first_name': 'Johnathan',
#   'full_name': 'Johnathan Joseph',
#   'gsis_id': '00-0024239',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/9610.png',
#   'height': '5-11',
#   'high_school': 'Northwestern (SC)',
#   'jersey_number': 25.0,
#   'last_name': 'Joseph',
#   'pff_id': 2969.0,
#   'position': 'CB',
#   'rotowire_id': 4768.0,
#   'season': 2020,
#   'sleeper_id': 172,
#   'sportradar_id': '06dab231-dbbd-4ccb-8233-3c2d70318ee3',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 185.0,
#   'yahoo_id': 7773.0,
#   'years_exp': nan},
#  {'birth_date': '1988-10-31',
#   'college': 'Southeastern Louisiana',
#   'depth_chart_position': 'LCB',
#   'espn_id': 15817.0,
#   'fantasy_data_id': 15177.0,
#   'first_name': 'Robert',
#   'full_name': 'Robert Alford',
#   'gsis_id': '00-0030528',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15817.png',
#   'height': '5-10',
#   'high_school': 'Hammond (LA)',
#   'jersey_number': 23.0,
#   'last_name': 'Alford',
#   'pff_id': 7841.0,
#   'position': 'CB',
#   'rotowire_id': 8645.0,
#   'season': 2020,
#   'sleeper_id': 1540,
#   'sportradar_id': '4f5ca039-21f3-4045-9c2e-c0b4d5d564c5',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 186.0,
#   'yahoo_id': 26683.0,
#   'years_exp': nan},
#  {'birth_date': '1990-07-11',
#   'college': 'Louisiana State',
#   'depth_chart_position': 'LCB',
#   'espn_id': 13980.0,
#   'fantasy_data_id': 13415.0,
#   'first_name': 'Patrick',
#   'full_name': 'Patrick Peterson',
#   'gsis_id': '00-0027943',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/13980.png',
#   'height': '6-1',
#   'high_school': 'Ely (FL)',
#   'jersey_number': 21.0,
#   'last_name': 'Peterson',
#   'pff_id': 6157.0,
#   'position': 'CB',
#   'rotowire_id': 7300.0,
#   'season': 2020,
#   'sleeper_id': 972,
#   'sportradar_id': '9f3b934e-52d6-4e16-ae92-d3e60be10493',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 203.0,
#   'yahoo_id': 24792.0,
#   'years_exp': nan},
#  {'birth_date': '1989-10-26',
#   'college': 'Alabama',
#   'depth_chart_position': 'RCB',
#   'espn_id': 14940.0,
#   'fantasy_data_id': 13871.0,
#   'first_name': 'Dre',
#   'full_name': 'Dre Kirkpatrick',
#   'gsis_id': '00-0029560',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/14940.png',
#   'height': '6-2',
#   'high_school': 'Gadsden City (AL)',
#   'jersey_number': 20.0,
#   'last_name': 'Kirkpatrick',
#   'pff_id': 7023.0,
#   'position': 'CB',
#   'rotowire_id': 8163.0,
#   'season': 2020,
#   'sleeper_id': 1068,
#   'sportradar_id': 'e972d67d-8302-4c64-9c1c-bc3121b90af4',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 190.0,
#   'yahoo_id': 25727.0,
#   'years_exp': nan},
#  {'birth_date': '1997-10-06',
#   'college': 'Baylor',
#   'depth_chart_position': nan,
#   'espn_id': 4035402.0,
#   'fantasy_data_id': 21941.0,
#   'first_name': 'Chris',
#   'full_name': 'Chris Miller',
#   'gsis_id': '00-0036060',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035402.png',
#   'height': '6-0',
#   'high_school': 'Lone Star (TX)',
#   'jersey_number': 38.0,
#   'last_name': 'Miller',
#   'pff_id': nan,
#   'position': 'DB',
#   'rotowire_id': 14692.0,
#   'season': 2020,
#   'sleeper_id': 7432,
#   'sportradar_id': '2d969b4e-4da9-4bf6-abd7-02c5e607c080',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 191.0,
#   'yahoo_id': 33287.0,
#   'years_exp': nan},
#  {'birth_date': '1996-04-15',
#   'college': 'Southern Mississippi',
#   'depth_chart_position': nan,
#   'espn_id': 3123966.0,
#   'fantasy_data_id': 21251.0,
#   'first_name': 'Picasso',
#   'full_name': 'Picasso Nelson',
#   'gsis_id': '00-0035368',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3123966.png',
#   'height': '5-10',
#   'high_school': 'Oak Grove (MS)',
#   'jersey_number': 43.0,
#   'last_name': 'Nelson',
#   'pff_id': 30126.0,
#   'position': 'DB',
#   'rotowire_id': 14032.0,
#   'season': 2020,
#   'sleeper_id': 6344,
#   'sportradar_id': 'cff07c85-137a-4496-8df9-4f96f68f1318',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 195.0,
#   'yahoo_id': 32095.0,
#   'years_exp': nan},
#  {'birth_date': '1998-07-18',
#   'college': 'Washington State',
#   'depth_chart_position': 'NB',
#   'espn_id': 4043089.0,
#   'fantasy_data_id': 21635.0,
#   'first_name': 'Jalen',
#   'full_name': 'Jalen Thompson',
#   'gsis_id': '00-0035705',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4043089.png',
#   'height': '5-11',
#   'high_school': 'Downey (CA)',
#   'jersey_number': 34.0,
#   'last_name': 'Thompson',
#   'pff_id': 49116.0,
#   'position': 'DB',
#   'rotowire_id': 14330.0,
#   'season': 2020,
#   'sleeper_id': 6711,
#   'sportradar_id': '56992f39-70e7-4b6a-86da-0a4776504e7a',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 190.0,
#   'yahoo_id': 32623.0,
#   'years_exp': nan},
#  {'birth_date': '1993-03-10',
#   'college': 'Fresno State',
#   'depth_chart_position': 'SS',
#   'espn_id': 2579163.0,
#   'fantasy_data_id': 18521.0,
#   'first_name': 'Charles',
#   'full_name': 'Charles Washington',
#   'gsis_id': '00-0032560',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2579163.png',
#   'height': '5-10',
#   'high_school': 'Crespi (CA)',
#   'jersey_number': 28.0,
#   'last_name': 'Washington',
#   'pff_id': 11137.0,
#   'position': 'DB',
#   'rotowire_id': 11341.0,
#   'season': 2020,
#   'sleeper_id': 3714,
#   'sportradar_id': '7757384a-6b03-41fb-9c77-3c016a968d1c',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 192.0,
#   'yahoo_id': 29781.0,
#   'years_exp': nan},
#  {'birth_date': '1990-02-26',
#   'college': 'Southern Methodist',
#   'depth_chart_position': 'FS',
#   'espn_id': 15782.0,
#   'fantasy_data_id': 15011.0,
#   'first_name': 'Chris',
#   'full_name': 'Chris Banjo',
#   'gsis_id': '00-0029747',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15782.png',
#   'height': '5-10',
#   'high_school': 'Kempner (TX)',
#   'jersey_number': 31.0,
#   'last_name': 'Banjo',
#   'pff_id': 8419.0,
#   'position': 'DB',
#   'rotowire_id': 9101.0,
#   'season': 2020,
#   'sleeper_id': 1442,
#   'sportradar_id': '6c7704c2-f833-46aa-9f9c-d975d5ad1297',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 207.0,
#   'yahoo_id': 26621.0,
#   'years_exp': nan},
#  {'birth_date': '1997-03-14',
#   'college': 'Penn State',
#   'depth_chart_position': nan,
#   'espn_id': 3929648.0,
#   'fantasy_data_id': 20879.0,
#   'first_name': 'Shareef',
#   'full_name': 'Shareef Miller',
#   'gsis_id': '00-0035267',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3929648.png',
#   'height': '6-4',
#   'high_school': 'George Washington (PA)',
#   'jersey_number': 55.0,
#   'last_name': 'Miller',
#   'pff_id': 28307.0,
#   'position': 'DE',
#   'rotowire_id': 13499.0,
#   'season': 2020,
#   'sleeper_id': 5900,
#   'sportradar_id': '26d3edb9-e572-4272-835a-21b63200ea64',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 256.0,
#   'yahoo_id': 31970.0,
#   'years_exp': nan},
#  {'birth_date': '1996-05-05',
#   'college': 'Temple',
#   'depth_chart_position': nan,
#   'espn_id': 3138765.0,
#   'fantasy_data_id': 21141.0,
#   'first_name': 'Michael',
#   'full_name': 'Michael Dogbe',
#   'gsis_id': '00-0035541',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3138765.png',
#   'height': '6-3',
#   'high_school': 'Parsippany Hills (NJ)',
#   'jersey_number': 91.0,
#   'last_name': 'Dogbe',
#   'pff_id': 48850.0,
#   'position': 'DE',
#   'rotowire_id': 13709.0,
#   'season': 2020,
#   'sleeper_id': 6304,
#   'sportradar_id': 'cf0c253d-45bd-48f5-9602-88c3d9ca1082',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 284.0,
#   'yahoo_id': 32081.0,
#   'years_exp': nan},
#  {'birth_date': '1990-01-17',
#   'college': 'Oklahoma',
#   'depth_chart_position': nan,
#   'espn_id': 15906.0,
#   'fantasy_data_id': 15069.0,
#   'first_name': 'Stacy',
#   'full_name': 'Stacy McGee',
#   'gsis_id': '00-0030515',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15906.png',
#   'height': '6-3',
#   'high_school': 'Muskogee (OK)',
#   'jersey_number': 65.0,
#   'last_name': 'McGee',
#   'pff_id': 7987.0,
#   'position': 'DE',
#   'rotowire_id': 8964.0,
#   'season': 2020,
#   'sleeper_id': 1474,
#   'sportradar_id': '0606c9ab-8351-4a38-8ca4-ceb16e982f6a',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 341.0,
#   'yahoo_id': 26828.0,
#   'years_exp': nan},
#  {'birth_date': '1991-02-17',
#   'college': 'Stanford',
#   'depth_chart_position': nan,
#   'espn_id': 17017.0,
#   'fantasy_data_id': 16153.0,
#   'first_name': 'Josh',
#   'full_name': 'Josh Mauro',
#   'gsis_id': '00-0030883',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/17017.png',
#   'height': '6-6',
#   'high_school': 'L.D. Bell (TX)',
#   'jersey_number': 69.0,
#   'last_name': 'Mauro',
#   'pff_id': 9003.0,
#   'position': 'DE',
#   'rotowire_id': 9412.0,
#   'season': 2020,
#   'sleeper_id': 1920,
#   'sportradar_id': '6399b33c-6d3d-4fc5-b142-1a5deb33ef76',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 290.0,
#   'yahoo_id': 27815.0,
#   'years_exp': nan},
#  {'birth_date': '1992-03-07',
#   'college': 'Stanford',
#   'depth_chart_position': nan,
#   'espn_id': 2517779.0,
#   'fantasy_data_id': 16911.0,
#   'first_name': 'David',
#   'full_name': 'David Parry',
#   'gsis_id': '00-0031592',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2517779.png',
#   'height': '6-2',
#   'high_school': 'Linn-Marr (IA)',
#   'jersey_number': 75.0,
#   'last_name': 'Parry',
#   'pff_id': 9584.0,
#   'position': 'DT',
#   'rotowire_id': 10461.0,
#   'season': 2020,
#   'sleeper_id': 2454,
#   'sportradar_id': '376a61bd-de05-4fb1-a698-7f93fd1a102c',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 317.0,
#   'yahoo_id': 28539.0,
#   'years_exp': nan},
#  {'birth_date': '1992-11-14',
#   'college': 'Auburn',
#   'depth_chart_position': 'RDE',
#   'espn_id': 2574582.0,
#   'fantasy_data_id': 16861.0,
#   'first_name': 'Angelo',
#   'full_name': 'Angelo Blackson',
#   'gsis_id': '00-0032107',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2574582.png',
#   'height': '6-4',
#   'high_school': 'Red Lion Christian Academy (DE)',
#   'jersey_number': 96.0,
#   'last_name': 'Blackson',
#   'pff_id': 9533.0,
#   'position': 'DT',
#   'rotowire_id': 10453.0,
#   'season': 2020,
#   'sleeper_id': 2405,
#   'sportradar_id': 'e9799059-f592-47e8-aab3-e2027fe7b148',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 318.0,
#   'yahoo_id': 28488.0,
#   'years_exp': nan},
#  {'birth_date': '1998-08-23',
#   'college': 'Utah',
#   'depth_chart_position': 'DT',
#   'espn_id': 4035666.0,
#   'fantasy_data_id': 22083.0,
#   'first_name': 'Leki',
#   'full_name': 'Leki Fotu',
#   'gsis_id': '00-0036371',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035666.png',
#   'height': '6-5',
#   'high_school': 'Herriman (UT)',
#   'jersey_number': 95.0,
#   'last_name': 'Fotu',
#   'pff_id': 44614.0,
#   'position': 'DT',
#   'rotowire_id': 14712.0,
#   'season': 2020,
#   'sleeper_id': 6948,
#   'sportradar_id': '2040899a-0b04-4de7-900b-f9e6861c6150',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 335.0,
#   'yahoo_id': 32784.0,
#   'years_exp': nan},
#  {'birth_date': '1997-08-20',
#   'college': 'Boston College',
#   'depth_chart_position': 'DT',
#   'espn_id': 3915282.0,
#   'fantasy_data_id': 20738.0,
#   'first_name': 'Zach',
#   'full_name': 'Zach Allen',
#   'gsis_id': '00-0035248',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3915282.png',
#   'height': '6-4',
#   'high_school': 'New Canaan (CT)',
#   'jersey_number': 94.0,
#   'last_name': 'Allen',
#   'pff_id': 49605.0,
#   'position': 'DT',
#   'rotowire_id': 13742.0,
#   'season': 2020,
#   'sleeper_id': 5871,
#   'sportradar_id': 'f68685e7-9904-47bc-b39a-e1c813435385',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 281.0,
#   'yahoo_id': 31897.0,
#   'years_exp': nan},
#  {'birth_date': '1992-09-21',
#   'college': 'Oklahoma',
#   'depth_chart_position': 'RDE',
#   'espn_id': 2577466.0,
#   'fantasy_data_id': 16813.0,
#   'first_name': 'Jordan',
#   'full_name': 'Jordan Phillips',
#   'gsis_id': '00-0031557',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2577466.png',
#   'height': '6-6',
#   'high_school': 'Circle (KS)',
#   'jersey_number': 97.0,
#   'last_name': 'Phillips',
#   'pff_id': 9485.0,
#   'position': 'DT',
#   'rotowire_id': 10311.0,
#   'season': 2020,
#   'sleeper_id': 2357,
#   'sportradar_id': '023af11a-3aa1-4266-b163-31cf6369ef3b',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 341.0,
#   'yahoo_id': 28440.0,
#   'years_exp': nan},
#  {'birth_date': '1996-06-14',
#   'college': 'Arizona',
#   'depth_chart_position': nan,
#   'espn_id': 3910660.0,
#   'fantasy_data_id': 21124.0,
#   'first_name': 'P.J.',
#   'full_name': 'P.J. Johnson',
#   'gsis_id': '00-0035540',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3910660.png',
#   'height': '6-3',
#   'high_school': 'Luther Burbank (CA)',
#   'jersey_number': 94.0,
#   'last_name': 'Johnson',
#   'pff_id': 36493.0,
#   'position': 'DT',
#   'rotowire_id': 13573.0,
#   'season': 2020,
#   'sleeper_id': 6273,
#   'sportradar_id': '344f10b9-b272-4f2f-8d1e-468f38f59f5e',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 320.0,
#   'yahoo_id': 32061.0,
#   'years_exp': nan},
#  {'birth_date': '1994-08-11',
#   'college': 'Louisiana Tech',
#   'depth_chart_position': nan,
#   'espn_id': 2971881.0,
#   'fantasy_data_id': 18524.0,
#   'first_name': 'Kentrell',
#   'full_name': 'Kentrell Brice',
#   'gsis_id': '00-0032628',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2971881.png',
#   'height': '5-11',
#   'high_school': 'Ruston (LA)',
#   'jersey_number': 44.0,
#   'last_name': 'Brice',
#   'pff_id': 11142.0,
#   'position': 'FS',
#   'rotowire_id': 11204.0,
#   'season': 2020,
#   'sleeper_id': 3716,
#   'sportradar_id': '64d8dddf-b3fe-4146-8d08-36e9c0b6eede',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 200.0,
#   'yahoo_id': 29720.0,
#   'years_exp': nan},
#  {'birth_date': '1989-04-08',
#   'college': 'North Carolina State',
#   'depth_chart_position': 'RG',
#   'espn_id': 15025.0,
#   'fantasy_data_id': 14585.0,
#   'first_name': 'J.R.',
#   'full_name': 'J.R. Sweezy',
#   'gsis_id': '00-0029146',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15025.png',
#   'height': '6-5',
#   'high_school': 'Mooresville (NC)',
#   'jersey_number': 64.0,
#   'last_name': 'Sweezy',
#   'pff_id': 7209.0,
#   'position': 'G',
#   'rotowire_id': 8364.0,
#   'season': 2020,
#   'sleeper_id': 1243,
#   'sportradar_id': 'be62bf39-c737-416f-a1ea-6b9d61684a62',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 310.0,
#   'yahoo_id': 25935.0,
#   'years_exp': nan},
#  {'birth_date': '1996-02-20',
#   'college': 'Mississippi State',
#   'depth_chart_position': nan,
#   'espn_id': 3115482.0,
#   'fantasy_data_id': 21266.0,
#   'first_name': 'Deion',
#   'full_name': 'Deion Calhoun',
#   'gsis_id': '00-0035336',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3115482.png',
#   'height': '6-3',
#   'high_school': 'Restoration Academy (AL)',
#   'jersey_number': 63.0,
#   'last_name': 'Calhoun',
#   'pff_id': 46676.0,
#   'position': 'G',
#   'rotowire_id': 13845.0,
#   'season': 2020,
#   'sleeper_id': 6570,
#   'sportradar_id': '8b7ee20f-238e-4b6f-b43d-4f9624bf2534',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 310.0,
#   'yahoo_id': 32432.0,
#   'years_exp': nan},
#  {'birth_date': '1995-03-28',
#   'college': 'Oregon State',
#   'depth_chart_position': nan,
#   'espn_id': 3045286.0,
#   'fantasy_data_id': 19001.0,
#   'first_name': 'Sean',
#   'full_name': 'Sean Harlow',
#   'gsis_id': '00-0033511',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3045286.png',
#   'height': '6-4',
#   'high_school': 'San Clemente (CA)',
#   'jersey_number': 64.0,
#   'last_name': 'Harlow',
#   'pff_id': 11891.0,
#   'position': 'G',
#   'rotowire_id': 11796.0,
#   'season': 2020,
#   'sleeper_id': 4155,
#   'sportradar_id': 'f4f08533-c692-4aba-84fe-fc21101c7bda',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 284.0,
#   'yahoo_id': 30249.0,
#   'years_exp': nan},
#  {'birth_date': '1990-08-15',
#   'college': 'Syracuse',
#   'depth_chart_position': 'LG',
#   'espn_id': 15808.0,
#   'fantasy_data_id': 15094.0,
#   'first_name': 'Justin',
#   'full_name': 'Justin Pugh',
#   'gsis_id': '00-0030585',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15808.png',
#   'height': '6-5',
#   'high_school': 'Council Rock South (PA)',
#   'jersey_number': 67.0,
#   'last_name': 'Pugh',
#   'pff_id': 7800.0,
#   'position': 'G',
#   'rotowire_id': 8733.0,
#   'season': 2020,
#   'sleeper_id': 1496,
#   'sportradar_id': 'b6fe2eb8-3692-450a-98b3-11e47c8b6711',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 311.0,
#   'yahoo_id': 26642.0,
#   'years_exp': nan},
#  {'birth_date': '1995-08-21',
#   'college': 'Syracuse',
#   'depth_chart_position': nan,
#   'espn_id': 3122145.0,
#   'fantasy_data_id': 21160.0,
#   'first_name': 'Koda',
#   'full_name': 'Koda Martin',
#   'gsis_id': '00-0035431',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3122145.png',
#   'height': '6-6',
#   'high_school': 'Manvel (TX)',
#   'jersey_number': 60.0,
#   'last_name': 'Martin',
#   'pff_id': nan,
#   'position': 'G',
#   'rotowire_id': 13963.0,
#   'season': 2020,
#   'sleeper_id': 6560,
#   'sportradar_id': '1dc22599-4ce9-49c2-bc8a-179a50e13cc1',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 304.0,
#   'yahoo_id': 32546.0,
#   'years_exp': nan},
#  {'birth_date': '1991-11-09',
#   'college': 'Florida',
#   'depth_chart_position': 'LG',
#   'espn_id': 2512538.0,
#   'fantasy_data_id': 16894.0,
#   'first_name': 'Max',
#   'full_name': 'Max Garcia',
#   'gsis_id': '00-0032132',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2512538.png',
#   'height': '6-4',
#   'high_school': 'Norcross (GA)',
#   'jersey_number': 73.0,
#   'last_name': 'Garcia',
#   'pff_id': 9566.0,
#   'position': 'G',
#   'rotowire_id': 10279.0,
#   'season': 2020,
#   'sleeper_id': 2437,
#   'sportradar_id': 'f19b687d-b81f-4104-9151-92e2af7d234d',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 309.0,
#   'yahoo_id': 28521.0,
#   'years_exp': nan},
#  {'birth_date': '1982-03-02',
#   'college': 'Ohio State',
#   'depth_chart_position': 'PK',
#   'espn_id': 8461.0,
#   'fantasy_data_id': 11735.0,
#   'first_name': 'Mike',
#   'full_name': 'Mike Nugent',
#   'gsis_id': '00-0023482',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/8461.png',
#   'height': '5-10',
#   'high_school': 'Centerville (OH)',
#   'jersey_number': 2.0,
#   'last_name': 'Nugent',
#   'pff_id': nan,
#   'position': 'K',
#   'rotowire_id': 4441.0,
#   'season': 2020,
#   'sleeper_id': 658,
#   'sportradar_id': 'e017e12b-07a7-4a35-b837-2faa9ffe3ce8',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 190.0,
#   'yahoo_id': 7223.0,
#   'years_exp': nan},
#  {'birth_date': '1995-05-07',
#   'college': 'Arizona State',
#   'depth_chart_position': 'PK',
#   'espn_id': 3043234.0,
#   'fantasy_data_id': 19079.0,
#   'first_name': 'Zane',
#   'full_name': 'Zane Gonzalez',
#   'gsis_id': '00-0033862',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3043234.png',
#   'height': '6-0',
#   'high_school': 'Deer Park (TX)',
#   'jersey_number': 5.0,
#   'last_name': 'Gonzalez',
#   'pff_id': nan,
#   'position': 'K',
#   'rotowire_id': 11831.0,
#   'season': 2020,
#   'sleeper_id': 4233,
#   'sportradar_id': 'cd0f4ef0-9914-4125-be4d-804a72350ceb',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 202.0,
#   'yahoo_id': 30337.0,
#   'years_exp': nan},
#  {'birth_date': '1989-11-21',
#   'college': 'Nebraska',
#   'depth_chart_position': nan,
#   'espn_id': 16486.0,
#   'fantasy_data_id': 15854.0,
#   'first_name': 'Brett',
#   'full_name': 'Brett Maher',
#   'gsis_id': '00-0030332',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/16486.png',
#   'height': '6-1',
#   'high_school': 'Kearney (NE)',
#   'jersey_number': 2.0,
#   'last_name': 'Maher',
#   'pff_id': nan,
#   'position': 'K',
#   'rotowire_id': 9054.0,
#   'season': 2020,
#   'sleeper_id': 4958,
#   'sportradar_id': '99c9de87-7fe1-4d5e-928e-586f48af2d79',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 185.0,
#   'yahoo_id': 27369.0,
#   'years_exp': nan},
#  {'birth_date': '1994-08-09',
#   'college': 'Sioux Falls',
#   'depth_chart_position': 'SLB',
#   'espn_id': 4334300.0,
#   'fantasy_data_id': 20085.0,
#   'first_name': 'Dennis',
#   'full_name': 'Dennis Gardeck',
#   'gsis_id': '00-0034473',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4334300.png',
#   'height': '6-0',
#   'high_school': 'Crystal Lake South (IL)',
#   'jersey_number': 45.0,
#   'last_name': 'Gardeck',
#   'pff_id': 66928.0,
#   'position': 'LB',
#   'rotowire_id': 13210.0,
#   'season': 2020,
#   'sleeper_id': 5158,
#   'sportradar_id': '48700b7b-210c-4ced-9c57-3e21162e7752',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 232.0,
#   'yahoo_id': 31299.0,
#   'years_exp': nan},
#  {'birth_date': '1991-06-24',
#   'college': 'Southern California',
#   'depth_chart_position': 'OLB',
#   'espn_id': 16820.0,
#   'fantasy_data_id': 16397.0,
#   'first_name': 'Devon',
#   'full_name': 'Devon Kennard',
#   'gsis_id': '00-0031241',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/16820.png',
#   'height': '6-3',
#   'high_school': 'Desert Vista (AZ)',
#   'jersey_number': 42.0,
#   'last_name': 'Kennard',
#   'pff_id': 8809.0,
#   'position': 'LB',
#   'rotowire_id': 9377.0,
#   'season': 2020,
#   'sleeper_id': 2084,
#   'sportradar_id': '036131ed-3862-4f06-8379-084d3b2352d5',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 256.0,
#   'yahoo_id': 27702.0,
#   'years_exp': nan},
#  {'birth_date': '1992-07-28',
#   'college': 'Clemson',
#   'depth_chart_position': nan,
#   'espn_id': 2576482.0,
#   'fantasy_data_id': 16792.0,
#   'first_name': 'Stephone',
#   'full_name': 'Stephone Anthony',
#   'gsis_id': '00-0032102',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2576482.png',
#   'height': '6-3',
#   'high_school': 'Anson (NC)',
#   'jersey_number': 58.0,
#   'last_name': 'Anthony',
#   'pff_id': 9464.0,
#   'position': 'LB',
#   'rotowire_id': 10355.0,
#   'season': 2020,
#   'sleeper_id': 2336,
#   'sportradar_id': 'e2a4fca8-0482-442e-93f7-3cef0fb2358d',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 245.0,
#   'yahoo_id': 28419.0,
#   'years_exp': nan},
#  {'birth_date': '1996-06-09',
#   'college': 'Washington',
#   'depth_chart_position': 'LILB',
#   'espn_id': 3894901.0,
#   'fantasy_data_id': 20088.0,
#   'first_name': 'Ezekiel',
#   'full_name': 'Ezekiel Turner',
#   'gsis_id': '00-0034490',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3894901.png',
#   'height': '6-2',
#   'high_school': 'Glen Burnie (MD)',
#   'jersey_number': 47.0,
#   'last_name': 'Turner',
#   'pff_id': 49167.0,
#   'position': 'LB',
#   'rotowire_id': 13222.0,
#   'season': 2020,
#   'sleeper_id': 5161,
#   'sportradar_id': '83849bc5-0b6c-4c76-b622-9c7042758e97',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 214.0,
#   'yahoo_id': 31324.0,
#   'years_exp': nan},
#  {'birth_date': '1994-10-11',
#   'college': 'Utah',
#   'depth_chart_position': 'SLB',
#   'espn_id': 3047582.0,
#   'fantasy_data_id': 19965.0,
#   'first_name': 'Kylie',
#   'full_name': 'Kylie Fitts',
#   'gsis_id': '00-0034404',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3047582.png',
#   'height': '6-3',
#   'high_school': 'Redlands East Valley (CA)',
#   'jersey_number': 49.0,
#   'last_name': 'Fitts',
#   'pff_id': 48553.0,
#   'position': 'LB',
#   'rotowire_id': 12823.0,
#   'season': 2020,
#   'sleeper_id': 5069,
#   'sportradar_id': 'ec198436-31b1-458e-a47b-9d1cd134300f',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 260.0,
#   'yahoo_id': 31151.0,
#   'years_exp': nan},
#  {'birth_date': '1992-06-27',
#   'college': 'Texas',
#   'depth_chart_position': 'RILB',
#   'espn_id': 2514270.0,
#   'fantasy_data_id': 16845.0,
#   'first_name': 'Jordan',
#   'full_name': 'Jordan Hicks',
#   'gsis_id': '00-0032129',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2514270.png',
#   'height': '6-1',
#   'high_school': 'Lakota West (OH)',
#   'jersey_number': 58.0,
#   'last_name': 'Hicks',
#   'pff_id': 9517.0,
#   'position': 'LB',
#   'rotowire_id': 10452.0,
#   'season': 2020,
#   'sleeper_id': 2389,
#   'sportradar_id': '4f090881-03fc-4a34-b02f-fd1df1e411de',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 236.0,
#   'yahoo_id': 28472.0,
#   'years_exp': nan},
#  {'birth_date': '1994-09-22',
#   'college': 'Temple',
#   'depth_chart_position': 'LB',
#   'espn_id': 2980504.0,
#   'fantasy_data_id': 18909.0,
#   'first_name': 'Haason',
#   'full_name': 'Haason Reddick',
#   'gsis_id': '00-0033875',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2980504.png',
#   'height': '6-1',
#   'high_school': 'Haddon Heights (NJ)',
#   'jersey_number': 43.0,
#   'last_name': 'Reddick',
#   'pff_id': 11768.0,
#   'position': 'LB',
#   'rotowire_id': 11937.0,
#   'season': 2020,
#   'sleeper_id': 4063,
#   'sportradar_id': 'ee399a97-6868-4db1-9381-09073914c2d6',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 235.0,
#   'yahoo_id': 30126.0,
#   'years_exp': nan},
#  {'birth_date': '1994-12-16',
#   'college': 'Boise State',
#   'depth_chart_position': 'RILB',
#   'espn_id': 3042895.0,
#   'fantasy_data_id': 19071.0,
#   'first_name': 'Tanner',
#   'full_name': 'Tanner Vallejo',
#   'gsis_id': '00-0033580',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3042895.png',
#   'height': '6-1',
#   'high_school': 'Nevada Union (CA)',
#   'jersey_number': 51.0,
#   'last_name': 'Vallejo',
#   'pff_id': 11950.0,
#   'position': 'LB',
#   'rotowire_id': 11982.0,
#   'season': 2020,
#   'sleeper_id': 4225,
#   'sportradar_id': '23f29e42-92e5-41b2-88eb-b9fb17a0eede',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 228.0,
#   'yahoo_id': 30308.0,
#   'years_exp': nan},
#  {'birth_date': '1991-03-13',
#   'college': 'Missouri',
#   'depth_chart_position': 'OLB',
#   'espn_id': 2971432.0,
#   'fantasy_data_id': 16819.0,
#   'first_name': 'Markus',
#   'full_name': 'Markus Golden',
#   'gsis_id': '00-0032127',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2971432.png',
#   'height': '6-3',
#   'high_school': 'Afton (MO)',
#   'jersey_number': 44.0,
#   'last_name': 'Golden',
#   'pff_id': 9491.0,
#   'position': 'LB',
#   'rotowire_id': 10329.0,
#   'season': 2020,
#   'sleeper_id': 2363,
#   'sportradar_id': '78eb0872-fff0-4fc2-94ee-6a5c518ecaa5',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 260.0,
#   'yahoo_id': 28446.0,
#   'years_exp': nan},
#  {'birth_date': '1994-04-12',
#   'college': 'Miami',
#   'depth_chart_position': nan,
#   'espn_id': 3051925.0,
#   'fantasy_data_id': 19591.0,
#   'first_name': 'Jamal',
#   'full_name': 'Jamal Carter',
#   'gsis_id': '00-0033819',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3051925.png',
#   'height': '6-1',
#   'high_school': 'Southridge (FL)',
#   'jersey_number': 35.0,
#   'last_name': 'Carter',
#   'pff_id': 49282.0,
#   'position': 'LB',
#   'rotowire_id': 11987.0,
#   'season': 2020,
#   'sleeper_id': 4689,
#   'sportradar_id': '1fc0af83-3c6e-4f4d-aadf-233e501c7241',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 215.0,
#   'yahoo_id': 30848.0,
#   'years_exp': nan},
#  {'birth_date': '1993-07-01',
#   'college': 'Minnesota',
#   'depth_chart_position': 'LILB',
#   'espn_id': 3040180.0,
#   'fantasy_data_id': 18037.0,
#   'first_name': "De'Vondre",
#   'full_name': "De'Vondre Campbell",
#   'gsis_id': '00-0032401',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3040180.png',
#   'height': '6-4',
#   'high_school': 'Cypress Lake (FL)',
#   'jersey_number': 59.0,
#   'last_name': 'Campbell',
#   'pff_id': 10749.0,
#   'position': 'LB',
#   'rotowire_id': 10935.0,
#   'season': 2020,
#   'sleeper_id': 3276,
#   'sportradar_id': '25a643a9-3b59-4739-8430-2713a818fb69',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 232.0,
#   'yahoo_id': 29349.0,
#   'years_exp': nan},
#  {'birth_date': '1990-02-27',
#   'college': 'Syracuse',
#   'depth_chart_position': 'SLB',
#   'espn_id': 14927.0,
#   'fantasy_data_id': 13749.0,
#   'first_name': 'Chandler',
#   'full_name': 'Chandler Jones',
#   'gsis_id': '00-0029585',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/14927.png',
#   'height': '6-5',
#   'high_school': 'Union-Endicott (NY)',
#   'jersey_number': 55.0,
#   'last_name': 'Jones',
#   'pff_id': 7027.0,
#   'position': 'LB',
#   'rotowire_id': 8140.0,
#   'season': 2020,
#   'sleeper_id': 1038,
#   'sportradar_id': '5197def5-f444-4561-ad28-7aac10dc748e',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 265.0,
#   'yahoo_id': 25731.0,
#   'years_exp': nan},
#  {'birth_date': '1996-04-22',
#   'college': 'Kansas State',
#   'depth_chart_position': nan,
#   'espn_id': 4046605.0,
#   'fantasy_data_id': 22383.0,
#   'first_name': 'Reggie',
#   'full_name': 'Reggie Walker',
#   'gsis_id': '00-0035923',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4046605.png',
#   'height': '6-2',
#   'high_school': 'Ponchatoula (LA)',
#   'jersey_number': 56.0,
#   'last_name': 'Walker',
#   'pff_id': 26885.0,
#   'position': 'LB',
#   'rotowire_id': 15102.0,
#   'season': 2020,
#   'sleeper_id': 7398,
#   'sportradar_id': '75513062-bfe5-4e32-af04-04a805c0fd8d',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 250.0,
#   'yahoo_id': 33086.0,
#   'years_exp': nan},
#  {'birth_date': '1994-06-09',
#   'college': 'San Jose State',
#   'depth_chart_position': 'LB',
#   'espn_id': 3043197.0,
#   'fantasy_data_id': 19433.0,
#   'first_name': 'Isaiah',
#   'full_name': 'Isaiah Irving',
#   'gsis_id': '00-0033635',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3043197.png',
#   'height': '6-3',
#   'high_school': 'Cypress Creek (TX)',
#   'jersey_number': 54.0,
#   'last_name': 'Irving',
#   'pff_id': 12171.0,
#   'position': 'LB',
#   'rotowire_id': 12445.0,
#   'season': 2020,
#   'sleeper_id': 4552,
#   'sportradar_id': '983aee62-70d8-4d39-a857-da6fee82bef1',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 254.0,
#   'yahoo_id': 30722.0,
#   'years_exp': nan},
#  {'birth_date': '1993-05-03',
#   'college': 'Florida State',
#   'depth_chart_position': nan,
#   'espn_id': 2576809.0,
#   'fantasy_data_id': 18180.0,
#   'first_name': 'Terrance',
#   'full_name': 'Terrance Smith',
#   'gsis_id': '00-0032820',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2576809.png',
#   'height': '6-2',
#   'high_school': 'Southwest DeKalb (GA)',
#   'jersey_number': 54.0,
#   'last_name': 'Smith',
#   'pff_id': 11181.0,
#   'position': 'LB',
#   'rotowire_id': 11179.0,
#   'season': 2020,
#   'sleeper_id': 3417,
#   'sportradar_id': 'dc447507-2380-494c-96c9-e0edb2679a3c',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 235.0,
#   'yahoo_id': 29885.0,
#   'years_exp': nan},
#  {'birth_date': '1998-08-11',
#   'college': 'California',
#   'depth_chart_position': nan,
#   'espn_id': 4035875.0,
#   'fantasy_data_id': 22002.0,
#   'first_name': 'Evan',
#   'full_name': 'Evan Weaver',
#   'gsis_id': '00-0036381',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035875.png',
#   'height': '6-3',
#   'high_school': 'Gonzaga Prep (WA)',
#   'jersey_number': 50.0,
#   'last_name': 'Weaver',
#   'pff_id': nan,
#   'position': 'LB',
#   'rotowire_id': 14752.0,
#   'season': 2020,
#   'sleeper_id': 7040,
#   'sportradar_id': '41dabf34-2055-4420-8aef-c222d7df48e6',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 245.0,
#   'yahoo_id': 32872.0,
#   'years_exp': nan},
#  {'birth_date': '1998-07-26',
#   'college': 'Clemson',
#   'depth_chart_position': 'LILB',
#   'espn_id': 4035462.0,
#   'fantasy_data_id': 22004.0,
#   'first_name': 'Isaiah',
#   'full_name': 'Isaiah Simmons',
#   'gsis_id': '00-0036356',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035462.png',
#   'height': '6-3',
#   'high_school': 'Olathe North (KS)',
#   'jersey_number': 48.0,
#   'last_name': 'Simmons',
#   'pff_id': 42451.0,
#   'position': 'LB',
#   'rotowire_id': 14525.0,
#   'season': 2020,
#   'sleeper_id': 6781,
#   'sportradar_id': 'b87d80b7-f129-4f3d-938a-1272f8122589',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 225.0,
#   'yahoo_id': 32678.0,
#   'years_exp': nan},
#  {'birth_date': '1990-07-05',
#   'college': 'San Diego State',
#   'depth_chart_position': nan,
#   'espn_id': 15241.0,
#   'fantasy_data_id': 14042.0,
#   'first_name': 'Aaron',
#   'full_name': 'Aaron Brewer',
#   'gsis_id': '00-0028946',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15241.png',
#   'height': '6-5',
#   'high_school': 'Troy (CA)',
#   'jersey_number': 46.0,
#   'last_name': 'Brewer',
#   'pff_id': 7301.0,
#   'position': 'LS',
#   'rotowire_id': 8543.0,
#   'season': 2020,
#   'sleeper_id': 1122,
#   'sportradar_id': '99149c69-e14f-4e05-9c3a-8ae7e3b1f00b',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 232.0,
#   'yahoo_id': 25976.0,
#   'years_exp': nan},
#  {'birth_date': '1988-06-08',
#   'college': 'Kentucky',
#   'depth_chart_position': 'NT',
#   'espn_id': 13292.0,
#   'fantasy_data_id': 11437.0,
#   'first_name': 'Corey',
#   'full_name': 'Corey Peters',
#   'gsis_id': '00-0027686',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/13292.png',
#   'height': '6-3',
#   'high_school': 'Central (KY)',
#   'jersey_number': 98.0,
#   'last_name': 'Peters',
#   'pff_id': 5607.0,
#   'position': 'NT',
#   'rotowire_id': 6682.0,
#   'season': 2020,
#   'sleeper_id': 608,
#   'sportradar_id': 'a50e3085-370b-4fd2-b79a-28d3b9c5c1c7',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 335.0,
#   'yahoo_id': 24058.0,
#   'years_exp': nan},
#  {'birth_date': '1998-08-27',
#   'college': 'Louisiana State',
#   'depth_chart_position': 'RDE',
#   'espn_id': 4035452.0,
#   'fantasy_data_id': 21885.0,
#   'first_name': 'Rashard',
#   'full_name': 'Rashard Lawrence',
#   'gsis_id': '00-0036373',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035452.png',
#   'height': '6-2',
#   'high_school': 'Neville (LA)',
#   'jersey_number': 92.0,
#   'last_name': 'Lawrence',
#   'pff_id': 44515.0,
#   'position': 'NT',
#   'rotowire_id': 14717.0,
#   'season': 2020,
#   'sleeper_id': 7004,
#   'sportradar_id': '6e9763f5-2f5c-45d4-b50b-d7bbf91e1a65',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 308.0,
#   'yahoo_id': 32801.0,
#   'years_exp': nan},
#  {'birth_date': '1984-11-27',
#   'college': 'Michigan State',
#   'depth_chart_position': 'NT',
#   'espn_id': 9709.0,
#   'fantasy_data_id': 5929.0,
#   'first_name': 'Domata',
#   'full_name': 'Domata Peko',
#   'gsis_id': '00-0024338',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/9709.png',
#   'height': '6-3',
#   'high_school': 'Pago Pago (ASM)',
#   'jersey_number': 90.0,
#   'last_name': 'Peko',
#   'pff_id': 3068.0,
#   'position': 'NT',
#   'rotowire_id': 5853.0,
#   'season': 2020,
#   'sleeper_id': 236,
#   'sportradar_id': '6a3bcfd5-a855-4173-a2aa-94e2c77c8268',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 325.0,
#   'yahoo_id': 7872.0,
#   'years_exp': nan},
#  {'birth_date': '1982-08-11',
#   'college': 'Pittsburgh',
#   'depth_chart_position': nan,
#   'espn_id': 5713.0,
#   'fantasy_data_id': 3100.0,
#   'first_name': 'Andy',
#   'full_name': 'Andy Lee',
#   'gsis_id': '00-0022824',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/5713.png',
#   'height': '6-1',
#   'high_school': 'West Oak (SC)',
#   'jersey_number': 4.0,
#   'last_name': 'Lee',
#   'pff_id': 1906.0,
#   'position': 'P',
#   'rotowire_id': 4044.0,
#   'season': 2020,
#   'sleeper_id': 112,
#   'sportradar_id': 'edaad8e3-62cd-4715-b225-0010ee9825a0',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 185.0,
#   'yahoo_id': 6947.0,
#   'years_exp': nan},
#  {'birth_date': '1997-08-07',
#   'college': 'Oklahoma',
#   'depth_chart_position': 'QB',
#   'espn_id': 3917315.0,
#   'fantasy_data_id': 20889.0,
#   'first_name': 'Kyler',
#   'full_name': 'Kyler Murray',
#   'gsis_id': '00-0035228',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3917315.png',
#   'height': '5-10',
#   'high_school': 'Allen (TX)',
#   'jersey_number': 1.0,
#   'last_name': 'Murray',
#   'pff_id': 38334.0,
#   'position': 'QB',
#   'rotowire_id': 13613.0,
#   'season': 2020,
#   'sleeper_id': 5849,
#   'sportradar_id': 'dd5a6b6e-ffae-45a5-b8e6-718a9251f374',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 207.0,
#   'yahoo_id': 31833.0,
#   'years_exp': nan},
#  {'birth_date': '1995-01-06',
#   'college': 'South Dakota',
#   'depth_chart_position': 'QB',
#   'espn_id': 3040206.0,
#   'fantasy_data_id': 21866.0,
#   'first_name': 'Chris',
#   'full_name': 'Chris Streveler',
#   'gsis_id': '00-0035752',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3040206.png',
#   'height': '6-3',
#   'high_school': 'Marian Central Catholic (IL)',
#   'jersey_number': 15.0,
#   'last_name': 'Streveler',
#   'pff_id': 46440.0,
#   'position': 'QB',
#   'rotowire_id': 14587.0,
#   'season': 2020,
#   'sleeper_id': 6778,
#   'sportradar_id': '23461354-f2d7-4e36-9046-fe9cde6dd413',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 215.0,
#   'yahoo_id': 32662.0,
#   'years_exp': nan},
#  {'birth_date': '1993-06-15',
#   'college': 'UCLA',
#   'depth_chart_position': 'QB',
#   'espn_id': 2577189.0,
#   'fantasy_data_id': 16907.0,
#   'first_name': 'Brett',
#   'full_name': 'Brett Hundley',
#   'gsis_id': '00-0031589',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2577189.png',
#   'height': '6-3',
#   'high_school': 'Chandler (AZ)',
#   'jersey_number': 7.0,
#   'last_name': 'Hundley',
#   'pff_id': 9580.0,
#   'position': 'QB',
#   'rotowire_id': 9706.0,
#   'season': 2020,
#   'sleeper_id': 2450,
#   'sportradar_id': 'e97f5ca9-186e-4346-ae65-1cd757ada455',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 226.0,
#   'yahoo_id': 28535.0,
#   'years_exp': nan},
#  {'birth_date': '1994-01-26',
#   'college': 'Alabama',
#   'depth_chart_position': 'RB',
#   'espn_id': 2979843.0,
#   'fantasy_data_id': 18003.0,
#   'first_name': 'Kenyan',
#   'full_name': 'Kenyan Drake',
#   'gsis_id': '00-0033118',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2979843.png',
#   'height': '6-1',
#   'high_school': 'Hillgrove (GA)',
#   'jersey_number': 41.0,
#   'last_name': 'Drake',
#   'pff_id': 10707.0,
#   'position': 'RB',
#   'rotowire_id': 11002.0,
#   'season': 2020,
#   'sleeper_id': 3242,
#   'sportradar_id': 'a0b93053-d349-4dd1-a840-24577102699b',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 211.0,
#   'yahoo_id': 29307.0,
#   'years_exp': nan},
#  {'birth_date': '1996-04-13',
#   'college': 'Fordham',
#   'depth_chart_position': 'RB',
#   'espn_id': 3119195.0,
#   'fantasy_data_id': 19919.0,
#   'first_name': 'Chase',
#   'full_name': 'Chase Edmonds',
#   'gsis_id': '00-0034681',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3119195.png',
#   'height': '5-9',
#   'high_school': 'Central Dauphin East (PA)',
#   'jersey_number': 29.0,
#   'last_name': 'Edmonds',
#   'pff_id': 45851.0,
#   'position': 'RB',
#   'rotowire_id': 12667.0,
#   'season': 2020,
#   'sleeper_id': 5000,
#   'sportradar_id': 'd8d9b161-7ef4-42bf-89b7-7edf806a0ad1',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 210.0,
#   'yahoo_id': 31104.0,
#   'years_exp': nan},
#  {'birth_date': '1994-09-26',
#   'college': 'California',
#   'depth_chart_position': nan,
#   'espn_id': 3052143.0,
#   'fantasy_data_id': 19129.0,
#   'first_name': 'Khalfani',
#   'full_name': 'Khalfani Muhammad',
#   'gsis_id': '00-0033797',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3052143.png',
#   'height': '5-7',
#   'high_school': 'Notre Dame (CA)',
#   'jersey_number': 33.0,
#   'last_name': 'Muhammad',
#   'pff_id': 11996.0,
#   'position': 'RB',
#   'rotowire_id': 12089.0,
#   'season': 2020,
#   'sleeper_id': 4283,
#   'sportradar_id': 'd16f5060-d562-492b-9ab8-4a495920e808',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 174.0,
#   'yahoo_id': 30355.0,
#   'years_exp': nan},
#  {'birth_date': '1999-04-13',
#   'college': 'Arizona State',
#   'depth_chart_position': nan,
#   'espn_id': 4242873.0,
#   'fantasy_data_id': 21773.0,
#   'first_name': 'Eno',
#   'full_name': 'Eno Benjamin',
#   'gsis_id': '00-0036383',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4242873.png',
#   'height': '5-10',
#   'high_school': 'Wylie East (TX)',
#   'jersey_number': 26.0,
#   'last_name': 'Benjamin',
#   'pff_id': nan,
#   'position': 'RB',
#   'rotowire_id': 14372.0,
#   'season': 2020,
#   'sleeper_id': 6951,
#   'sportradar_id': 'aebf7b65-da15-4499-b1af-6687fa50b2e4',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 210.0,
#   'yahoo_id': 32892.0,
#   'years_exp': nan},
#  {'birth_date': '1993-11-22',
#   'college': 'Arizona State',
#   'depth_chart_position': nan,
#   'espn_id': 2978124.0,
#   'fantasy_data_id': 18253.0,
#   'first_name': 'D.J.',
#   'full_name': 'D.J. Foster',
#   'gsis_id': '00-0032577',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2978124.png',
#   'height': '6-0',
#   'high_school': 'Saguaro (AZ)',
#   'jersey_number': 37.0,
#   'last_name': 'Foster',
#   'pff_id': 11214.0,
#   'position': 'RB',
#   'rotowire_id': 11004.0,
#   'season': 2020,
#   'sleeper_id': 3488,
#   'sportradar_id': '39d12962-65a4-4107-8924-56f48fce31ef',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 205.0,
#   'yahoo_id': 29872.0,
#   'years_exp': nan},
#  {'birth_date': '1997-09-30',
#   'college': 'Central Michigan',
#   'depth_chart_position': 'RB',
#   'espn_id': 4039274.0,
#   'fantasy_data_id': 21782.0,
#   'first_name': 'Jonathan',
#   'full_name': 'Jonathan Ward',
#   'gsis_id': '00-0035924',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4039274.png',
#   'height': '6-0',
#   'high_school': 'Bishop McNamara (IL)',
#   'jersey_number': 38.0,
#   'last_name': 'Ward',
#   'pff_id': 25859.0,
#   'position': 'RB',
#   'rotowire_id': 15106.0,
#   'season': 2020,
#   'sleeper_id': 7087,
#   'sportradar_id': '1dc6b133-355f-451e-856f-d02839681578',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 202.0,
#   'yahoo_id': 33088.0,
#   'years_exp': nan},
#  {'birth_date': '1992-03-27',
#   'college': 'Southern California',
#   'depth_chart_position': nan,
#   'espn_id': 2971605.0,
#   'fantasy_data_id': 16881.0,
#   'first_name': 'Josh',
#   'full_name': 'Josh Shaw',
#   'gsis_id': '00-0032168',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2971605.png',
#   'height': '6-1',
#   'high_school': 'Palmdale (CA)',
#   'jersey_number': 27.0,
#   'last_name': 'Shaw',
#   'pff_id': 9553.0,
#   'position': 'SS',
#   'rotowire_id': 10420.0,
#   'season': 2020,
#   'sleeper_id': 2425,
#   'sportradar_id': '1686f2b7-90e8-4d0a-89f8-415310ae2bd8',
#   'status': 'Inactive',
#   'team': 'ARI',
#   'weight': 200.0,
#   'yahoo_id': 28508.0,
#   'years_exp': nan},
#  {'birth_date': '1997-02-11',
#   'college': 'Alabama',
#   'depth_chart_position': 'SS',
#   'espn_id': 3859100.0,
#   'fantasy_data_id': 20729.0,
#   'first_name': 'Deionte',
#   'full_name': 'Deionte Thompson',
#   'gsis_id': '00-0035532',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3859100.png',
#   'height': '6-1',
#   'high_school': 'West Orange-Stark (TX)',
#   'jersey_number': 22.0,
#   'last_name': 'Thompson',
#   'pff_id': 25444.0,
#   'position': 'SS',
#   'rotowire_id': 13586.0,
#   'season': 2020,
#   'sleeper_id': 5866,
#   'sportradar_id': 'db3a0416-6758-485d-89e1-806af99e0991',
#   'status': 'Active',
#   'team': 'ARI',
#   'weight': 196.0,
#   'yahoo_id': 31971.0,
#   'years_exp': nan},
#  {'birth_date': '1996-01-10',
#   'college': 'Washington',
#   'depth_chart_position': 'FS',
#   'espn_id': 3127287.0,
#   'fantasy_data_id': 18927.0,
#   'first_name': 'Budda',
#   'full_name': 'Budda Baker',
#   'gsis_id': '00-0033890',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3127287.png',
#   'height': '5-10',
#   'high_school': 'Bellevue (WA)',
#   'jersey_number': 32.0,
#   'last_name': 'Baker',
# ...
#   'depth_chart_position': nan,
#   'espn_id': 3040661.0,
#   'fantasy_data_id': 18537.0,
#   'first_name': 'Brian',
#   'full_name': 'Brian Price',
#   'gsis_id': '00-0032649',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3040661.png',
#   'height': '6-3',
#   'high_school': 'McCutcheon (IN)',
#   'jersey_number': 78.0,
#   'last_name': 'Price',
#   'pff_id': 11157.0,
#   'position': 'DT',
#   'rotowire_id': 11566.0,
#   'season': 2020,
#   'sleeper_id': 3728,
#   'sportradar_id': 'eddd3f47-fdd1-4d53-9e31-93b46624fd0f',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 322.0,
#   'yahoo_id': 29747.0,
#   'years_exp': nan},
#  {'birth_date': '1989-11-22',
#   'college': 'Oklahoma State',
#   'depth_chart_position': 'LG',
#   'espn_id': 16549.0,
#   'fantasy_data_id': 15583.0,
#   'first_name': 'Lane',
#   'full_name': 'Lane Taylor',
#   'gsis_id': '00-0030273',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/16549.png',
#   'height': '6-3',
#   'high_school': 'Martin (TX)',
#   'jersey_number': 65.0,
#   'last_name': 'Taylor',
#   'pff_id': 8365.0,
#   'position': 'G',
#   'rotowire_id': 9104.0,
#   'season': 2020,
#   'sleeper_id': 1702,
#   'sportradar_id': 'f9ec0e39-86d2-4f99-84d6-b4e7bb387d8b',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 324.0,
#   'yahoo_id': 27360.0,
#   'years_exp': nan},
#  {'birth_date': '1994-03-09',
#   'college': 'Michigan',
#   'depth_chart_position': 'RG',
#   'espn_id': 2977626.0,
#   'fantasy_data_id': 19379.0,
#   'first_name': 'Ben',
#   'full_name': 'Ben Braden',
#   'gsis_id': '00-0033490',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2977626.png',
#   'height': '6-6',
#   'high_school': 'Rockford (MI)',
#   'jersey_number': 64.0,
#   'last_name': 'Braden',
#   'pff_id': 23112.0,
#   'position': 'G',
#   'rotowire_id': 11780.0,
#   'season': 2020,
#   'sleeper_id': 4507,
#   'sportradar_id': 'f4a43515-f437-499a-8c57-086eb579c5af',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 329.0,
#   'yahoo_id': 30676.0,
#   'years_exp': nan},
#  {'birth_date': '1989-10-21',
#   'college': 'Wisconsin',
#   'depth_chart_position': 'RT',
#   'espn_id': 15900.0,
#   'fantasy_data_id': 14905.0,
#   'first_name': 'Rick',
#   'full_name': 'Rick Wagner',
#   'gsis_id': '00-0029893',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/15900.png',
#   'height': '6-6',
#   'high_school': 'Nathan Hale (WI)',
#   'jersey_number': 71.0,
#   'last_name': 'Wagner',
#   'pff_id': 7950.0,
#   'position': 'G',
#   'rotowire_id': 8739.0,
#   'season': 2020,
#   'sleeper_id': 1382,
#   'sportradar_id': '2dff7d82-426e-42d6-8c7c-170ad3a24ad6',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 315.0,
#   'yahoo_id': 26791.0,
#   'years_exp': nan},
#  {'birth_date': '1997-01-19',
#   'college': 'North Dakota State',
#   'depth_chart_position': nan,
#   'espn_id': 3930912.0,
#   'fantasy_data_id': 22263.0,
#   'first_name': 'Zack',
#   'full_name': 'Zack Johnson',
#   'gsis_id': '00-0036015',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3930912.png',
#   'height': '6-6',
#   'high_school': 'Spring Lake Park (MN)',
#   'jersey_number': 68.0,
#   'last_name': 'Johnson',
#   'pff_id': nan,
#   'position': 'G',
#   'rotowire_id': 15114.0,
#   'season': 2020,
#   'sleeper_id': 7265,
#   'sportradar_id': '80422fa0-20c3-40d8-a3e6-93f55b09b872',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 315.0,
#   'yahoo_id': 33227.0,
#   'years_exp': nan},
#  {'birth_date': '1995-12-26',
#   'college': 'Mississippi State',
#   'depth_chart_position': 'RG',
#   'espn_id': 3115485.0,
#   'fantasy_data_id': 20828.0,
#   'first_name': 'Elgton',
#   'full_name': 'Elgton Jenkins',
#   'gsis_id': '00-0035526',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3115485.png',
#   'height': '6-5',
#   'high_school': 'Clarksdale (MS)',
#   'jersey_number': 74.0,
#   'last_name': 'Jenkins',
#   'pff_id': 46298.0,
#   'position': 'G',
#   'rotowire_id': 13669.0,
#   'season': 2020,
#   'sleeper_id': 5877,
#   'sportradar_id': 'b5d116d8-11d4-43b1-8f0b-9a3ba26648c9',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 310.0,
#   'yahoo_id': 31876.0,
#   'years_exp': nan},
#  {'birth_date': '1993-07-30',
#   'college': 'Duke',
#   'depth_chart_position': 'LG',
#   'espn_id': 2576736.0,
#   'fantasy_data_id': 18710.0,
#   'first_name': 'Lucas',
#   'full_name': 'Lucas Patrick',
#   'gsis_id': '00-0033082',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2576736.png',
#   'height': '6-3',
#   'high_school': 'Brentwood (TN)',
#   'jersey_number': 62.0,
#   'last_name': 'Patrick',
#   'pff_id': 11435.0,
#   'position': 'G',
#   'rotowire_id': 11453.0,
#   'season': 2020,
#   'sleeper_id': 3888,
#   'sportradar_id': 'e9615c8c-3a7e-4b10-92f8-86f48edbe9a4',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 313.0,
#   'yahoo_id': 30018.0,
#   'years_exp': nan},
#  {'birth_date': '1997-08-08',
#   'college': 'Michigan',
#   'depth_chart_position': 'LG',
#   'espn_id': 3929936.0,
#   'fantasy_data_id': 22040.0,
#   'first_name': 'Jon',
#   'full_name': 'Jon Runyan',
#   'gsis_id': '00-0036246',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3929936.png',
#   'height': '6-5',
#   'high_school': "St. Joseph's Prep (PA)",
#   'jersey_number': 76.0,
#   'last_name': 'Runyan',
#   'pff_id': 36661.0,
#   'position': 'G',
#   'rotowire_id': 14471.0,
#   'season': 2020,
#   'sleeper_id': 6980,
#   'sportradar_id': '13bbc7df-2a25-44db-a79a-89ba6c1ac009',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 321.0,
#   'yahoo_id': 32862.0,
#   'years_exp': nan},
#  {'birth_date': '1997-05-15',
#   'college': 'Indiana',
#   'depth_chart_position': 'RG',
#   'espn_id': 3929794.0,
#   'fantasy_data_id': 22042.0,
#   'first_name': 'Simon',
#   'full_name': 'Simon Stepaniak',
#   'gsis_id': '00-0036242',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3929794.png',
#   'height': '6-4',
#   'high_school': 'Ross (OH)',
#   'jersey_number': 72.0,
#   'last_name': 'Stepaniak',
#   'pff_id': nan,
#   'position': 'G',
#   'rotowire_id': 14594.0,
#   'season': 2020,
#   'sleeper_id': 7067,
#   'sportradar_id': '7e6798b8-b33f-4a35-ab5b-67fafd8d9e65',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 311.0,
#   'yahoo_id': 32879.0,
#   'years_exp': nan},
#  {'birth_date': '1984-09-03',
#   'college': 'Colorado',
#   'depth_chart_position': 'PK',
#   'espn_id': 10636.0,
#   'fantasy_data_id': 1694.0,
#   'first_name': 'Mason',
#   'full_name': 'Mason Crosby',
#   'gsis_id': '00-0025580',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/10636.png',
#   'height': '6-1',
#   'high_school': 'Georgetown (TX)',
#   'jersey_number': 2.0,
#   'last_name': 'Crosby',
#   'pff_id': 3809.0,
#   'position': 'K',
#   'rotowire_id': 5363.0,
#   'season': 2020,
#   'sleeper_id': 59,
#   'sportradar_id': 'e0856548-6fd5-4f83-9aa0-91f1bf4cbbd8',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 207.0,
#   'yahoo_id': 8447.0,
#   'years_exp': nan},
#  {'birth_date': '1997-11-01',
#   'college': 'Arkansas',
#   'depth_chart_position': nan,
#   'espn_id': 4035577.0,
#   'fantasy_data_id': 21991.0,
#   'first_name': "De'Jon",
#   'full_name': "De'Jon Harris",
#   'gsis_id': '00-0036090',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035577.png',
#   'height': '6-0',
#   'high_school': 'John Ehret (LA)',
#   'jersey_number': 59.0,
#   'last_name': 'Harris',
#   'pff_id': nan,
#   'position': 'LB',
#   'rotowire_id': 14553.0,
#   'season': 2020,
#   'sleeper_id': 7504,
#   'sportradar_id': '8ca83e4e-d3a5-4dcb-a917-e58e36b77721',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 244.0,
#   'yahoo_id': 33321.0,
#   'years_exp': nan},
#  {'birth_date': '1992-11-17',
#   'college': 'Mississippi State',
#   'depth_chart_position': 'LOLB',
#   'espn_id': 2577446.0,
#   'fantasy_data_id': 16799.0,
#   'first_name': 'Preston',
#   'full_name': 'Preston Smith',
#   'gsis_id': '00-0031935',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2577446.png',
#   'height': '6-5',
#   'high_school': 'Stephenson (GA)',
#   'jersey_number': 91.0,
#   'last_name': 'Smith',
#   'pff_id': 9471.0,
#   'position': 'LB',
#   'rotowire_id': 10316.0,
#   'season': 2020,
#   'sleeper_id': 2343,
#   'sportradar_id': 'ede260be-5ae6-4a06-887b-e4a130932705',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 265.0,
#   'yahoo_id': 28426.0,
#   'years_exp': nan},
#  {'birth_date': '1997-12-03',
#   'college': 'Michigan',
#   'depth_chart_position': 'LOLB',
#   'espn_id': 4046523.0,
#   'fantasy_data_id': 20767.0,
#   'first_name': 'Rashan',
#   'full_name': 'Rashan Gary',
#   'gsis_id': '00-0034967',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4046523.png',
#   'height': '6-5',
#   'high_school': 'Paramus Catholic (NJ)',
#   'jersey_number': 52.0,
#   'last_name': 'Gary',
#   'pff_id': 42905.0,
#   'position': 'LB',
#   'rotowire_id': 13651.0,
#   'season': 2020,
#   'sleeper_id': 5839,
#   'sportradar_id': '99847f76-5bf2-4cbe-8573-9a477f7fb472',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 277.0,
#   'yahoo_id': 31844.0,
#   'years_exp': nan},
#  {'birth_date': '1999-07-28',
#   'college': 'Miami',
#   'depth_chart_position': 'LOLB',
#   'espn_id': 4240655.0,
#   'fantasy_data_id': 21906.0,
#   'first_name': 'Jonathan',
#   'full_name': 'Jonathan Garvin',
#   'gsis_id': '00-0036239',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4240655.png',
#   'height': '6-4',
#   'high_school': 'Lake Worth (FL)',
#   'jersey_number': 53.0,
#   'last_name': 'Garvin',
#   'pff_id': 56703.0,
#   'position': 'LB',
#   'rotowire_id': 14365.0,
#   'season': 2020,
#   'sleeper_id': 6965,
#   'sportradar_id': '586bc34d-f368-4d82-96b1-816d08fa2837',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 250.0,
#   'yahoo_id': 32912.0,
#   'years_exp': nan},
#  {'birth_date': '1995-03-21',
#   'college': 'Vanderbilt',
#   'depth_chart_position': 'RILB',
#   'espn_id': 3051746.0,
#   'fantasy_data_id': 19902.0,
#   'first_name': 'Oren',
#   'full_name': 'Oren Burks',
#   'gsis_id': '00-0034754',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3051746.png',
#   'height': '6-3',
#   'high_school': 'South County (VA)',
#   'jersey_number': 42.0,
#   'last_name': 'Burks',
#   'pff_id': 50203.0,
#   'position': 'LB',
#   'rotowire_id': 12919.0,
#   'season': 2020,
#   'sleeper_id': 5031,
#   'sportradar_id': 'ab9bd5b1-eaf9-4f2d-8acd-fbc143980b17',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 233.0,
#   'yahoo_id': 31058.0,
#   'years_exp': nan},
#  {'birth_date': '1995-12-31',
#   'college': 'Texas Christian',
#   'depth_chart_position': 'LILB',
#   'espn_id': 3116431.0,
#   'fantasy_data_id': 21125.0,
#   'first_name': 'Ty',
#   'full_name': 'Ty Summers',
#   'gsis_id': '00-0034999',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3116431.png',
#   'height': '6-1',
#   'high_school': 'Reagan (TX)',
#   'jersey_number': 44.0,
#   'last_name': 'Summers',
#   'pff_id': 30242.0,
#   'position': 'LB',
#   'rotowire_id': 13883.0,
#   'season': 2020,
#   'sleeper_id': 6294,
#   'sportradar_id': '5203e275-5554-47de-bc0a-5b13639e5b50',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 240.0,
#   'yahoo_id': 32058.0,
#   'years_exp': nan},
#  {'birth_date': '1992-09-08',
#   'college': 'Kentucky',
#   'depth_chart_position': 'ROLB',
#   'espn_id': 3043168.0,
#   'fantasy_data_id': 16883.0,
#   'first_name': "Za'Darius",
#   'full_name': "Za'Darius Smith",
#   'gsis_id': '00-0031576',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3043168.png',
#   'height': '6-4',
#   'high_school': 'Greenville (AL)',
#   'jersey_number': 55.0,
#   'last_name': 'Smith',
#   'pff_id': 9555.0,
#   'position': 'LB',
#   'rotowire_id': 10328.0,
#   'season': 2020,
#   'sleeper_id': 2427,
#   'sportradar_id': 'af3599a5-5eb4-4dd4-87ab-e0032ebfa644',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 272.0,
#   'yahoo_id': 28510.0,
#   'years_exp': nan},
#  {'birth_date': '1998-04-02',
#   'college': 'UCLA',
#   'depth_chart_position': 'LILB',
#   'espn_id': 4035817.0,
#   'fantasy_data_id': 22266.0,
#   'first_name': 'Krys',
#   'full_name': 'Krys Barnes',
#   'gsis_id': '00-0035961',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4035817.png',
#   'height': '6-1',
#   'high_school': 'Liberty (CA)',
#   'jersey_number': 51.0,
#   'last_name': 'Barnes',
#   'pff_id': 42548.0,
#   'position': 'LB',
#   'rotowire_id': 14572.0,
#   'season': 2020,
#   'sleeper_id': 7268,
#   'sportradar_id': 'fc081a72-124d-4648-86a4-45aebb95a5ba',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 235.0,
#   'yahoo_id': 33221.0,
#   'years_exp': nan},
#  {'birth_date': '1998-06-17',
#   'college': 'Minnesota',
#   'depth_chart_position': 'RILB',
#   'espn_id': 4034781.0,
#   'fantasy_data_id': 22007.0,
#   'first_name': 'Kamal',
#   'full_name': 'Kamal Martin',
#   'gsis_id': '00-0036270',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/4034781.png',
#   'height': '6-3',
#   'high_school': 'Burnsville (MN)',
#   'jersey_number': 54.0,
#   'last_name': 'Martin',
#   'pff_id': 12744.0,
#   'position': 'LB',
#   'rotowire_id': 14385.0,
#   'season': 2020,
#   'sleeper_id': 6890,
#   'sportradar_id': 'e1917291-e27c-4221-b62e-36b5d9df254c',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 245.0,
#   'yahoo_id': 32845.0,
#   'years_exp': nan},
#  {'birth_date': '1995-09-07',
#   'college': 'Arkansas',
#   'depth_chart_position': 'ROLB',
#   'espn_id': 3128675.0,
#   'fantasy_data_id': 21417.0,
#   'first_name': 'Randy',
#   'full_name': 'Randy Ramsey',
#   'gsis_id': '00-0035085',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/3128675.png',
#   'height': '6-3',
#   'high_school': 'Dillard (FL)',
#   'jersey_number': 56.0,
#   'last_name': 'Ramsey',
#   'pff_id': 39094.0,
#   'position': 'LB',
#   'rotowire_id': 14106.0,
#   'season': 2020,
#   'sleeper_id': 6517,
#   'sportradar_id': '3267e534-526e-4db8-8e1f-49fc7ee8aedb',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 236.0,
#   'yahoo_id': 32276.0,
#   'years_exp': nan},
#  {'birth_date': '1994-03-09',
#   'college': 'Louisville',
#   'depth_chart_position': 'LILB',
#   'espn_id': 2970181.0,
#   'fantasy_data_id': 18208.0,
#   'first_name': 'James',
#   'full_name': 'James Burgess',
#   'gsis_id': '00-0032627',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2970181.png',
#   'height': '6-0',
#   'high_school': 'Homestead (FL)',
#   'jersey_number': 57.0,
#   'last_name': 'Burgess',
#   'pff_id': 11202.0,
#   'position': 'LB',
#   'rotowire_id': 11646.0,
#   'season': 2020,
#   'sleeper_id': 3444,
#   'sportradar_id': '0b06c168-c660-440a-922e-954ac15c0df0',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 230.0,
#   'yahoo_id': 29822.0,
#   'years_exp': nan},
#  {'birth_date': '1992-08-31',
#   'college': 'Iowa',
#   'depth_chart_position': 'RILB',
#   'espn_id': 16767.0,
#   'fantasy_data_id': 16133.0,
#   'first_name': 'Christian',
#   'full_name': 'Christian Kirksey',
#   'gsis_id': '00-0031361',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/16767.png',
#   'height': '6-2',
#   'high_school': 'Hazelwood East (MO)',
#   'jersey_number': 58.0,
#   'last_name': 'Kirksey',
#   'pff_id': 8706.0,
#   'position': 'LB',
#   'rotowire_id': 9375.0,
#   'season': 2020,
#   'sleeper_id': 1905,
#   'sportradar_id': '462bfd22-1159-408f-8f92-7fde712ffc3a',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 235.0,
#   'yahoo_id': 27599.0,
#   'years_exp': nan},
#  {'birth_date': '1994-05-21',
#   'college': 'Mississippi State',
#   'depth_chart_position': nan,
#   'espn_id': 2980350.0,
#   'fantasy_data_id': 20061.0,
#   'first_name': 'Hunter',
#   'full_name': 'Hunter Bradley',
#   'gsis_id': '00-0034168',
#   'headshot_url': 'https://a.espncdn.com/combiner/i?img=/i/headshots/nfl/players/full/2980350.png',
#   'height': '6-3',
#   'high_school': 'Collierville (TN)',
#   'jersey_number': 43.0,
#   'last_name': 'Bradley',
#   'pff_id': 23250.0,
#   'position': 'LS',
#   'rotowire_id': 12660.0,
#   'season': 2020,
#   'sleeper_id': 5321,
#   'sportradar_id': 'f1fdaa82-25bb-4ae7-8945-c0b9864214ca',
#   'status': 'Active',
#   'team': 'GB',
#   'weight': 240.0,
#   'yahoo_id': 31209.0,
#   'years_exp': nan},
#  ...]

# %%
pd.DataFrame(requests.post('https://nflfastr.herokuapp.com/api/v1.0/roster/2020', json = json).json())
# Out:
#      first_name    last_name position team
# 0         Mason         Cole        C  ARI
# 1        Lamont     Gaillard        C  ARI
# 2         Byron       Murphy       CB  ARI
# 3        Prince    Amukamara       CB  ARI
# 4          Jace    Whittaker       CB  ARI
# 5         Kevin     Peterson       CB  ARI
# 6     Johnathan       Joseph       CB  ARI
# 7        Robert       Alford       CB  ARI
# 8       Patrick     Peterson       CB  ARI
# 9           Dre  Kirkpatrick       CB  ARI
# 10        Chris       Miller       DB  ARI
# 11      Picasso       Nelson       DB  ARI
# 12        Jalen     Thompson       DB  ARI
# 13      Charles   Washington       DB  ARI
# 14        Chris        Banjo       DB  ARI
# 15      Shareef       Miller       DE  ARI
# 16      Michael        Dogbe       DE  ARI
# 17        Stacy        McGee       DE  ARI
# 18         Josh        Mauro       DE  ARI
# 19        David        Parry       DT  ARI
# 20       Angelo     Blackson       DT  ARI
# 21         Leki         Fotu       DT  ARI
# 22         Zach        Allen       DT  ARI
# 23       Jordan     Phillips       DT  ARI
# 24         P.J.      Johnson       DT  ARI
# 25     Kentrell        Brice       FS  ARI
# 26         J.R.       Sweezy        G  ARI
# 27        Deion      Calhoun        G  ARI
# 28         Sean       Harlow        G  ARI
# 29       Justin         Pugh        G  ARI
# ...         ...          ...      ...  ...
# 4594     Speedy         Noil       WR  SEA
# 4595       Zach     Franklin       CB   SF
# 4596       Adam       Shuler       DE   SF
# 4597       Glen       Coffee       RB   SF
# 4598      Corey      Griffin        S   SF
# 4599    Charlie   Taumoepeau       TE   SF
# 4600      Chris        Finke       WR   SF
# 4601       Zach  Shackelford        C   TB
# 4602     Donell      Stanley        C   TB
# 4603    Deondre      Barnett       DE   TB
# 4604        Sam       Renner       DT   TB
# 4605       Alex         Gray       FS   TB
# 4606        Dax   Dellenbach       LS   TB
# 4607     Austin     Albrecht       OL   TB
# 4608      Aaron        Davis       SS   TB
# 4609     Thomas     Sperbeck       WR   TB
# 4610       Evan      Perroni     None   TB
# 4611       Ryan     McKinley       CB  TEN
# 4612   Roderick    Henderson       DT  TEN
# 4613    Elijaah        Goins       FS  TEN
# 4614     Johnny        Ragin      ILB  TEN
# 4615        Jan      Johnson       LB  TEN
# 4616      Mason       Kinsey       WR  TEN
# 4617    Quinton     Schooley        C  WAS
# 4618   DeMarkus          Acy       DB  WAS
# 4619       Sean        Welsh        G  WAS
# 4620    Michael       Warren       RB  WAS
# 4621      Javon        Leake       RB  WAS
# 4622       Kano       Dillon       TE  WAS
# 4623      Mikah       Holder       WR  WAS
#
# [4624 rows x 4 columns]
